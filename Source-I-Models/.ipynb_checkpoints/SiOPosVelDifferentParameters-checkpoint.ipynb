# %%
import numpy as np
import pandas as pd
import math
from SiOModel import SiOModel
from matplotlib import pyplot as plt
import astropy as ast
from astropy.io import fits
from astropy.visualization import astropy_mpl_style


# Adjust these parameters to control the shape of the outflow lobes
# r = r0 + r1 * abs(z) + r2 * sqrt(abs(z)); units = AU

# ----------------------------------------------------------------------------------------------#
r_inner_base = 6                      # inner radius at base of outflow from the circumstellar disk
r_inner_lin = .1                       # linear factor for inner radius
r_inner_par = 4                        # parabolic factor for inner radius
r_outer_base = 15.                     # outer radius at base of outflow from the circumstellar disk
r_outer_lin = 0.05                     # linear factor for outer radius
r_outer_par = 10                        # parabolic factor for outer radius
theta = math.radians(10.)             # angle of outflow axis to plane of sky 
# ----------------------------------------------------------------------------------------------#



# Test and Deprecated Variables
# ----------------------------------------------------------------------------------------------#
#r_inner_angle = math.atan(.25)        # angle relating linear increase in inner radius with z
#r_outer_angle = math.atan(.50)        # angle relating linear increase in outer radius with z
#theta = 0                             # test angle of outflow axis to plane of sky 
# ----------------------------------------------------------------------------------------------#



# Adjust these parameters to control the velocity field inside the outflow shells
# ----------------------------------------------------------------------------------------------#
v_radial_0 = 10.         # radial expansion speed at all z
v_phi_0 = 12.            # rotational velocity at zprime=0 (in the disk). Does not include the dropoff.
v_z_0 = 18.0             # expansion speed along outflow axis
z_no_rotation = 600.   # rotataional velocity drops to 0 at height z_no_rotation (AU)
# ----------------------------------------------------------------------------------------------#



# Randomness Parameters
# ----------------------------------------------------------------------------------------------#
seed = 510920758332
v_rand = 4
# ----------------------------------------------------------------------------------------------#

### Create model instance with parameters above ###
model_instance = SiOModel(r_inner_base, r_outer_base, r_inner_lin, r_outer_lin, r_inner_par, r_outer_par, 0, theta, v_radial_0, 0, v_phi_0, v_z_0, v_rand, z_no_rotation, seed)

# %% [markdown]
# # Radius Parameter

# %%
radius_graph =model_instance.radius_graph()

# %% [markdown]
# # Velocity Parameters

# %%
velocity_graph_radial = model_instance.velocity_radial_expansion_graph()

# %%
velocity_graph_rotation = model_instance.velocity_rotation_graph()
# Out:
# [13.889045136017197]
# [1.8890451360171983]
# [13.889045136017197, 14.371925661060095]
# [1.8890451360171983, 2.3719256610600947]
# [13.889045136017197, 14.371925661060095, 14.91891891891892]
# [1.8890451360171983, 2.3719256610600947, 2.9189189189189184]
# [13.889045136017197, 14.371925661060095, 14.91891891891892, 15.581562246553144]
# [1.8890451360171983, 2.3719256610600947, 2.9189189189189184, 3.581562246553143]
# [13.889045136017197, 14.371925661060095, 14.91891891891892, 15.581562246553144, 16.0]
# [1.8890451360171983, 2.3719256610600947, 2.9189189189189184, 3.581562246553143, 4.0]
# [13.889045136017197, 14.371925661060095, 14.91891891891892, 15.581562246553144, 16.0, 15.581562246553144]
# [1.8890451360171983, 2.3719256610600947, 2.9189189189189184, 3.581562246553143, 4.0, 3.581562246553143]
# [13.889045136017197, 14.371925661060095, 14.91891891891892, 15.581562246553144, 16.0, 15.581562246553144, 14.91891891891892]
# [1.8890451360171983, 2.3719256610600947, 2.9189189189189184, 3.581562246553143, 4.0, 3.581562246553143, 2.9189189189189184]
# [13.889045136017197, 14.371925661060095, 14.91891891891892, 15.581562246553144, 16.0, 15.581562246553144, 14.91891891891892, 14.371925661060095]
# [1.8890451360171983, 2.3719256610600947, 2.9189189189189184, 3.581562246553143, 4.0, 3.581562246553143, 2.9189189189189184, 2.3719256610600947]
# [13.889045136017197, 14.371925661060095, 14.91891891891892, 15.581562246553144, 16.0, 15.581562246553144, 14.91891891891892, 14.371925661060095, 13.889045136017197]
# [1.8890451360171983, 2.3719256610600947, 2.9189189189189184, 3.581562246553143, 4.0, 3.581562246553143, 2.9189189189189184, 2.3719256610600947, 1.8890451360171983]

# %% [markdown]
# # Specific Angular Momentum

# %%
specific_angular_momentum = model_instance.specific_angular_momentum()
# Out:
# Velocity_rotational_inner_radius [13.889045136017197, 14.371925661060095, 14.91891891891892, 15.581562246553144, 16.0, 15.581562246553144, 14.91891891891892, 14.371925661060095, 13.889045136017197]
# Inner Radius [82.5685424949238, 69.98979485566356, 56.0, 39.2842712474619, 6.0, 39.2842712474619, 56.0, 69.98979485566356, 82.5685424949238]
# Velocity_rotational_outer_radius [1.8890451360171983, 2.3719256610600947, 2.9189189189189184, 3.581562246553143, 4.0, 3.581562246553143, 2.9189189189189184, 2.3719256610600947, 1.8890451360171983]
# Outer Radius [180.56349186104046, 157.2219358530748, 130.0, 95.28174593052023, 15.0, 95.28174593052023, 130.0, 157.2219358530748, 180.56349186104046]

# %% [markdown]
# # PV Plot

# %%
pv=model_instance.position_velocity()

# %%
#Parameters to be Found
#r_outer_base - Outer Radii of the Outflow - Done
#r_inner_base - Inner Radii of the Outflow - Done
#v_radial
# v_phi_0
#v_z_0
#theta
